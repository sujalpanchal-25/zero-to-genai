# %%
import pandas as pd

# %%
df = pd.read_csv("products-100.csv")

# %%
df
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
df.head(5)
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
# 2      3                  Smart Blender Cooker
# 3      4          Advanced Router Rechargeable
# 4      5          Portable Mouse Monitor Phone
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
#
#                         Brand            Category  Price Currency  Stock  \
# 0     Garner, Boyle and Flynn  Books & Stationery    265      USD    774
# 1                 Mueller Inc    Shoes & Footwear    502      USD     81
# 2  Lawson, Keller and Winters  Kitchen Appliances    227      USD    726
# ...

# %%
df.tail(5)
# Out:
#     Index                                   Name  \
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                          Description                        Brand  \
# 95  Investment everything story buy.                 Atkinson Inc
# 96    Nature notice themselves news.                     Shea Ltd
# 97  Understand still or summer rule.                     West Ltd
# 98              Final art some push.     Bell, Gamble and Barrett
# 99        However public major baby.  Hebert, Hughes and Trujillo
#
#                   Category  Price Currency  Stock            EAN       Color  \
# 95     Laptops & Computers    375      USD    703  3330396409604   Gainsboro
# 96  Beauty & Personal Care    289      USD    727  9265397743935       White
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Name', 'Description', 'Brand', 'Category', 'Price',
#        'Currency', 'Stock', 'EAN', 'Color', 'Size', 'Availability',
#        'Internal ID'],
#       dtype='str')

# %%
df.shape
# Out:
# (100, 13)

# %%
df.dtypes
# Out:
# Index           int64
# Name              str
# Description       str
# Brand             str
# Category          str
# Price           int64
# Currency          str
# Stock           int64
# EAN             int64
# Color             str
# Size              str
# Availability      str
# Internal ID     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Index         100 non-null    int64
#  1   Name          100 non-null    str
#  2   Description   100 non-null    str
#  3   Brand         100 non-null    str
#  4   Category      100 non-null    str
#  5   Price         100 non-null    int64
#  6   Currency      100 non-null    str
#  7   Stock         100 non-null    int64
#  8   EAN           100 non-null    int64
#  9   Color         100 non-null    str
#  10  Size          100 non-null    str
#  11  Availability  100 non-null    str
#  12  Internal ID   100 non-null    int64
# dtypes: int64(5), str(8)
# memory usage: 21.9 KB

# %%
df.describe()
# Out:
#             Index      Price       Stock           EAN  Internal ID
# count  100.000000  100.00000  100.000000  1.000000e+02   100.000000
# mean    50.500000  451.19000  545.710000  4.876267e+12    49.340000
# std     29.011492  281.60911  266.716863  2.918084e+12    28.078253
# min      1.000000    1.00000   10.000000  5.246382e+08     3.000000
# 25%     25.750000  230.75000  347.500000  2.062323e+12    25.000000
# 50%     50.500000  407.50000  575.500000  4.875720e+12    48.000000
# 75%     75.250000  679.00000  749.250000  7.676943e+12    74.500000
# max    100.000000  999.00000  998.000000  9.921752e+12    99.000000

# %%
df.describe(include='all')
# Out:
#              Index    Name                                    Description  \
# count   100.000000     100                                            100
# unique         NaN      99                                            100
# top            NaN  Tablet  Situation organization these memory much off.
# freq           NaN       2                                              1
# mean     50.500000     NaN                                            NaN
# std      29.011492     NaN                                            NaN
# min       1.000000     NaN                                            NaN
# 25%      25.750000     NaN                                            NaN
# 50%      50.500000     NaN                                            NaN
# 75%      75.250000     NaN                                            NaN
# max     100.000000     NaN                                            NaN
#
#                           Brand    Category      Price Currency       Stock  \
# ...

# %%
df.isna()
# Out:
#     Index   Name  Description  Brand  Category  Price  Currency  Stock    EAN  \
# 0   False  False        False  False     False  False     False  False  False
# 1   False  False        False  False     False  False     False  False  False
# 2   False  False        False  False     False  False     False  False  False
# 3   False  False        False  False     False  False     False  False  False
# 4   False  False        False  False     False  False     False  False  False
# ..    ...    ...          ...    ...       ...    ...       ...    ...    ...
# 95  False  False        False  False     False  False     False  False  False
# 96  False  False        False  False     False  False     False  False  False
# 97  False  False        False  False     False  False     False  False  False
# 98  False  False        False  False     False  False     False  False  False
# 99  False  False        False  False     False  False     False  False  False
#
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Brand, Category, Price, Currency, Stock, EAN, Color, Size, Availability, Internal ID]
# Index: []

# %%
df.isna().sum()
# Out:
# Index           0
# Name            0
# Description     0
# Brand           0
# Category        0
# Price           0
# Currency        0
# Stock           0
# EAN             0
# Color           0
# Size            0
# Availability    0
# Internal ID     0
# dtype: int64

# %%
df.isna().any()
# Out:
# Index           False
# Name            False
# Description     False
# Brand           False
# Category        False
# Price           False
# Currency        False
# Stock           False
# EAN             False
# Color           False
# Size            False
# Availability    False
# Internal ID     False
# dtype: bool

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().any().any()
# Out:
# np.False_

# %%
df[['Name','Price']]
# Out:
#                                      Name  Price
# 0    Compact Printer Air Advanced Digital    265
# 1                                  Tablet    502
# 2                    Smart Blender Cooker    227
# 3            Advanced Router Rechargeable    121
# 4            Portable Mouse Monitor Phone      1
# ..                                    ...    ...
# 95                                 Router    375
# 96     Fast Thermostat Microphone Scooter    289
# 97  Eco Heater Toaster Stove Silent Sense    232
# 98               Clean Blender Scale Lite    241
# 99                             Smart Lamp     71
#
# [100 rows x 2 columns]

# %%
df[df['Price']>500]
# Out:
#     Index                                               Name  \
# 1       2                                             Tablet
# 9      10                  Ultra Powerbank Brush Charger Max
# 12     13                                       Heater Radio
# 16     17                               Eco Iron Monitor Air
# 19     20                                         Cooler Fan
# 21     22              Wireless Powerbank 360 Advanced Ultra
# 22     23          Rechargeable Lamp Speakerphone Headphones
# 23     24                            Mini Scooter Microphone
# 24     25                    Rechargeable Webcam Stove Grill
# 25     26                       Mini Iron Drone Wireless Pro
# 27     28                        Wireless Webcam Stove Grill
# 28     29                                        Clock Brush
# 29     30                           Keyboard Toaster Monitor
# 32     33                     Advanced Microphone Cooler Eco
# ...

# %%
df[df['Stock']<20]
# Out:
#     Index                               Name  \
# 80     81  Fast Heater Cooker Compact Silent
# 84     85                      Fast Keyboard
#
#                           Description                     Brand  \
# 80  Strategy fund mind rather change.  Decker, Montes and Logan
# 84    Success other institution fear.                 Lewis Ltd
#
#             Category  Price Currency  Stock            EAN   Color      Size  \
# 80            Makeup    367      USD     19  3868467036959  Orchid   8x10 in
# 84  Camping & Hiking    998      USD     10  3163238295239    Cyan  50x70 cm
#
#      Availability  Internal ID
# 80       in_stock           15
# 84  limited_stock           64

# %%
df[df['Availability']=='in_stock']
# Out:
#     Index                                       Name  \
# 1       2                                     Tablet
# 2       3                       Smart Blender Cooker
# 20     21             Portable Camera Plus Air Ultra
# 28     29                                Clock Brush
# 43     44                                 Eco Vacuum
# 50     51                         Mini Fridge Camera
# 51     52     Rechargeable Tablet Plus Portable Mini
# 53     54      Wireless Light Toaster Lite Touch Eco
# 59     60        Automatic Speaker Router Lamp Prime
# 60     61                Smart Webcam Projector Lock
# 64     65                 Silent Trimmer Shaver Fast
# 66     67         Mini Charger Lock Oven Sense Sense
# 72     73                    Compact Thermostat Oven
# 75     76            Rechargeable Webcam Dock Heater
# 77     78                                      Brush
# 80     81          Fast Heater Cooker Compact Silent
# 83     84  Wireless Fan Thermostat Max Automatic Max
# ...

# %%
len(df[df['Availability']=='in_stock'])
# Out:
# 20

# %%
df[df['Brand']=='Sony']
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Brand, Category, Price, Currency, Stock, EAN, Color, Size, Availability, Internal ID]
# Index: []

# %%
df[(df['Price']>=200)&(df['Price']<=800)]
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 5       6                                  Radio
# 8       9                              Eco Radio
# ..    ...                                    ...
# 94     95                      Ultra Radio Radio
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 5   Character prove growth contain serious customer.
# 8                           Know father for act let.
# ...

# %%
df.iloc[:21]
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       3                            Smart Blender Cooker
# 3       4                    Advanced Router Rechargeable
# 4       5                    Portable Mouse Monitor Phone
# 5       6                                           Radio
# 6       7  Ultra Projector Oven Thermostat Prime Advanced
# 7       8                              Webcam Stove Grill
# 8       9                                       Eco Radio
# 9      10               Ultra Powerbank Brush Charger Max
# 10     11                                   Wireless Dock
# 11     12                    Fast Camera Router Fan Smart
# 12     13                                    Heater Radio
# 13     14                     Smart Trimmer Webcam Heater
# 14     15                              Webcam Dock Heater
# ...

# %%
df.iloc[10:21,2:7]
# Out:
#                                          Description  \
# 10                    Whole bill sound whether will.
# 11          Various above trouble itself crime form.
# 12  Ten do evidence billion perhaps read bank enter.
# 13                         Example available better.
# 14             State yet soon traditional your deal.
# 15             As east entire positive source their.
# 16  Color single indeed yard event popular food boy.
# 17              Accept campaign every research test.
# 18       Of price visit interesting enter three set.
# 19                          Fall billion city share.
# 20                      Reality hair explain up bad.
#
#                           Brand           Category  Price Currency
# 10                   Russo-West  Health & Wellness    257      USD
# 11             Vazquez and Sons  Cleaning Supplies    221      USD
# 12            Delgado-Blackwell            Cycling    689      USD
# ...

# %%
df[(df['Price']>500) & (df['Stock']>50)]
# Out:
#     Index                                               Name  \
# 1       2                                             Tablet
# 9      10                  Ultra Powerbank Brush Charger Max
# 12     13                                       Heater Radio
# 19     20                                         Cooler Fan
# 21     22              Wireless Powerbank 360 Advanced Ultra
# 22     23          Rechargeable Lamp Speakerphone Headphones
# 23     24                            Mini Scooter Microphone
# 24     25                    Rechargeable Webcam Stove Grill
# 25     26                       Mini Iron Drone Wireless Pro
# 27     28                        Wireless Webcam Stove Grill
# 28     29                                        Clock Brush
# 29     30                           Keyboard Toaster Monitor
# 32     33                     Advanced Microphone Cooler Eco
# 35     36                          Smart Phone Scooter Clean
# ...

# %%
len(df[(df['Price']>500) & (df['Stock']>50)])
# Out:
# 38

# %%
df.sort_values("Price",ascending=True)
# Out:
#     Index                                Name  \
# 4       5        Portable Mouse Monitor Phone
# 17     18  Digital Tablet Router Printer Lite
# 69     70     Compact Mouse Mouse Router Mini
# 70     71          Premium Lock Mini Advanced
# 87     88    Silent Scanner Monitor Treadmill
# ..    ...                                 ...
# 61     62                            Fast Fan
# 16     17                Eco Iron Monitor Air
# 28     29                         Clock Brush
# 84     85                       Fast Keyboard
# 41     42  Ultra Speakerphone Oven Go Smart X
#
#                                           Description  \
# 4   Feeling back religious however author room sci...
# 17               Accept campaign every research test.
# 69                     Occur miss son Democrat happy.
# 70                 Three character traditional maybe.
# 87  Do interesting suggest agreement range admit r...
# ..                                                ...
# ...

# %%
df[df['Price'].between(200,800)]
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 5       6                                  Radio
# 8       9                              Eco Radio
# ..    ...                                    ...
# 94     95                      Ultra Radio Radio
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 5   Character prove growth contain serious customer.
# 8                           Know father for act let.
# ...

# %%
df1 = df[df['Availability'] == 'in_stock']

# %%
df1[['Name','Price','Availability']]
# Out:
#                                          Name  Price Availability
# 1                                      Tablet    502     in_stock
# 2                        Smart Blender Cooker    227     in_stock
# 20             Portable Camera Plus Air Ultra    197     in_stock
# 28                                Clock Brush    985     in_stock
# 43                                 Eco Vacuum    259     in_stock
# 50                         Mini Fridge Camera    777     in_stock
# 51     Rechargeable Tablet Plus Portable Mini    820     in_stock
# 53      Wireless Light Toaster Lite Touch Eco    791     in_stock
# 59        Automatic Speaker Router Lamp Prime    621     in_stock
# 60                Smart Webcam Projector Lock    440     in_stock
# 64                 Silent Trimmer Shaver Fast    130     in_stock
# 66         Mini Charger Lock Oven Sense Sense    750     in_stock
# 72                    Compact Thermostat Oven    685     in_stock
# ...

# %%
df[(df['Price']>500) & (df['Availability']=='in_stock')]
# Out:
#     Index                                    Name  \
# 1       2                                  Tablet
# 28     29                             Clock Brush
# 50     51                      Mini Fridge Camera
# 51     52  Rechargeable Tablet Plus Portable Mini
# 53     54   Wireless Light Toaster Lite Touch Eco
# 59     60     Automatic Speaker Router Lamp Prime
# 66     67      Mini Charger Lock Oven Sense Sense
# 72     73                 Compact Thermostat Oven
# 75     76         Rechargeable Webcam Dock Heater
# 91     92       Portable Scooter Wireless Digital
#
#                                           Description  \
# 1         Discussion loss politics free one thousand.
# 28  Other another must explain send somebody consi...
# 50                    Little determine at huge month.
# 51                         Expect question how sound.
# 53                 Oil guy table industry hand which.
# 59      Word score education thousand high treatment.
# ...

# %%
df2 = df[df['Stock']<20]

# %%
df2
# Out:
#     Index                               Name  \
# 80     81  Fast Heater Cooker Compact Silent
# 84     85                      Fast Keyboard
#
#                           Description                     Brand  \
# 80  Strategy fund mind rather change.  Decker, Montes and Logan
# 84    Success other institution fear.                 Lewis Ltd
#
#             Category  Price Currency  Stock            EAN   Color      Size  \
# 80            Makeup    367      USD     19  3868467036959  Orchid   8x10 in
# 84  Camping & Hiking    998      USD     10  3163238295239    Cyan  50x70 cm
#
#      Availability  Internal ID
# 80       in_stock           15
# 84  limited_stock           64

# %%
df2[['Name','Brand','Stock']]
# Out:
#                                  Name                     Brand  Stock
# 80  Fast Heater Cooker Compact Silent  Decker, Montes and Logan     19
# 84                      Fast Keyboard                 Lewis Ltd     10

# %%
df[(df['Stock']<20) & (df['Price']>700)]
# Out:
#     Index           Name                      Description      Brand  \
# 84     85  Fast Keyboard  Success other institution fear.  Lewis Ltd
#
#             Category  Price Currency  Stock            EAN Color      Size  \
# 84  Camping & Hiking    998      USD     10  3163238295239  Cyan  50x70 cm
#
#      Availability  Internal ID
# 84  limited_stock           64

# %%
df[df['Availability'] == 'in_stock'][['Name','Price']]
# Out:
#                                          Name  Price
# 1                                      Tablet    502
# 2                        Smart Blender Cooker    227
# 20             Portable Camera Plus Air Ultra    197
# 28                                Clock Brush    985
# 43                                 Eco Vacuum    259
# 50                         Mini Fridge Camera    777
# 51     Rechargeable Tablet Plus Portable Mini    820
# 53      Wireless Light Toaster Lite Touch Eco    791
# 59        Automatic Speaker Router Lamp Prime    621
# 60                Smart Webcam Projector Lock    440
# 64                 Silent Trimmer Shaver Fast    130
# 66         Mini Charger Lock Oven Sense Sense    750
# 72                    Compact Thermostat Oven    685
# 75            Rechargeable Webcam Dock Heater    800
# 77                                      Brush    273
# 80          Fast Heater Cooker Compact Silent    367
# 83  Wireless Fan Thermostat Max Automatic Max    423
# ...
